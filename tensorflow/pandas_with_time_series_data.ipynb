# %% [markdown]
# # **Datetime Index**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline

# %%
from datetime import datetime

# %%
my_year = 2017
my_month = 1
my_day = 2
my_hour = 13
my_minute = 30
my_second = 15

# %%
my_date = datetime(my_year,my_month,my_day)
my_date
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
my_date_time = datetime(my_year, my_month, my_day,my_hour,my_minute, my_second)
my_date_time
# Out:
# datetime.datetime(2017, 1, 2, 13, 30, 15)

# %%
first_two = [datetime(2016,1,1), datetime(2016,1,2)]
first_two
# Out:
# [datetime.datetime(2016, 1, 1, 0, 0), datetime.datetime(2016, 1, 2, 0, 0)]

# %%
dt_index = pd.DatetimeIndex(first_two)
dt_index
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02'], dtype='datetime64[ns]', freq=None)

# %%
data = np.random.randn(2,2)
data
# Out:
# array([[-0.77518005, -1.14521087],
#        [ 1.62213359, -0.42444568]])

# %%
cols = ['a','b']

# %%
df = pd.DataFrame(data,dt_index,cols)
df
# Out:
#                    a         b
# 2016-01-01 -0.775180 -1.145211
# 2016-01-02  1.622134 -0.424446

# %%
df.index.argmax()
# Out:
# 1

# %%
df.index.max()
# Out:
# Timestamp('2016-01-02 00:00:00')

# %% [markdown]
# # **Time Resampling**

# %%
# !pip install quandl
import quandl
# Out:
# Requirement already satisfied: quandl in /usr/local/lib/python3.7/dist-packages (3.6.1)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.7/dist-packages (from quandl) (1.19.5)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from quandl) (0.5.1)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from quandl) (2.23.0)
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.7/dist-packages (from quandl) (1.1.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from quandl) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from quandl) (1.15.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from quandl) (8.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (1.24.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.14->quandl) (2018.9)

# %%
df = quandl.get('WIKI/FB')
df.head()
# Out:
#              Open   High    Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 2012-05-18  42.05  45.00  38.00  ...     38.00     38.2318  573576400.0
# 2012-05-21  36.53  36.66  33.00  ...     33.00     34.0300  168192700.0
# 2012-05-22  32.61  33.59  30.94  ...     30.94     31.0000  101786600.0
# 2012-05-23  31.37  32.50  31.36  ...     31.36     32.0000   73600000.0
# 2012-05-24  32.95  33.21  31.77  ...     31.77     33.0300   50237200.0
#
# [5 rows x 12 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2012-05-18', '2012-05-21', '2012-05-22', '2012-05-23',
#                '2012-05-24', '2012-05-25', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01',
#                ...
#                '2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19',
#                '2018-03-20', '2018-03-21', '2018-03-22', '2018-03-23',
#                '2018-03-26', '2018-03-27'],
#               dtype='datetime64[ns]', name='Date', length=1472, freq=None)

# %%
df.resample(rule='BQ').mean() #A=year end frequency, BA=business year end frequency, BQS=business quarter start frequency
# we have to call an aggregate function after resampling
# Out:
#                   Open        High  ...  Adj. Close   Adj. Volume
# Date                                ...
# 2012-06-29   30.579900   31.323293  ...   30.239193  6.398079e+07
# 2012-09-28   23.342222   23.763297  ...   23.188579  4.334569e+07
# 2012-12-31   23.483305   23.949194  ...   23.487724  6.161711e+07
# 2013-03-29   28.475683   28.929962  ...   28.445942  5.601120e+07
# 2013-06-28   25.692425   26.035377  ...   25.615555  3.920212e+07
# 2013-09-30   37.065694   37.677309  ...   37.214703  6.822023e+07
# 2013-12-31   50.233672   51.092109  ...   50.207438  7.667938e+07
# 2014-03-31   63.520656   64.404259  ...   63.368538  6.001523e+07
# 2014-06-30   61.543968   62.495737  ...   61.513456  6.137849e+07
# 2014-09-30   73.233047   74.026755  ...   73.356256  3.648454e+07
# 2014-12-31   76.399453   77.273880  ...   76.444375  3.295862e+07
# 2015-03-31   78.371902   79.168007  ...   78.340410  2.617305e+07
# 2015-06-30   81.644286   82.426024  ...   81.658968  2.384051e+07
# 2015-09-30   91.754687   92.934056  ...   91.761797  3.335401e+07
# 2015-12-31  102.645234  103.677625  ...  102.726172  2.436986e+07
# 2016-03-31  105.525082  106.942452  ...  105.512295  3.586895e+07
# 2016-06-30  115.301094  116.388450  ...  115.226719  2.583327e+07
# 2016-09-30  124.013438  124.865250  ...  124.139375  1.894315e+07
# 2016-12-30  123.095565  123.990825  ...  122.812063  2.185103e+07
# 2017-03-31  133.294315  134.281305  ...  133.637419  1.783555e+07
# 2017-06-30  148.689127  149.623795  ...  148.686825  1.696941e+07
# 2017-09-29  166.787619  167.963671  ...  166.873175  1.588590e+07
# 2017-12-29  176.736613  177.953192  ...  176.695968  1.518274e+07
# 2018-03-30  180.356102  182.579224  ...  180.355931  3.095545e+07
#
# [24 rows x 12 columns]

# %%
df.resample(rule='A').max()
# Out:
#               Open    High     Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                                ...
# 2012-12-31   42.05   45.00   38.00  ...     38.00     38.2318  573576400.0
# 2013-12-31   58.32   58.58   57.37  ...     57.37     57.9600  365457900.0
# 2014-12-31   82.02   82.17   80.75  ...     80.75     81.4500  150178900.0
# 2015-12-31  108.80  110.65  108.00  ...    108.00    109.0100   86211323.0
# 2016-12-31  133.50  135.60  132.22  ...    132.22    133.2800  107475327.0
# 2017-12-31  183.51  184.25  182.09  ...    182.09    183.0300   68065163.0
# 2018-12-31  192.04  195.32  189.98  ...    189.98    193.0900  128925534.0
#
# [7 rows x 12 columns]

# %%
def first_day(entry):
  return entry[0];

# %%
df.resample(rule='A').apply(first_day)
# Out:
#               Open    High     Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                                ...
# 2012-12-31   42.05   45.00   38.00  ...     38.00     38.2318  573576400.0
# 2013-12-31   27.44   28.18   27.42  ...     27.42     28.0000   69846400.0
# 2014-12-31   54.83   55.22   54.19  ...     54.19     54.7100   43195500.0
# 2015-12-31   78.58   78.93   77.70  ...     77.70     78.4500   18177475.0
# 2016-12-31  101.95  102.24   99.75  ...     99.75    102.2200   37912403.0
# 2017-12-31  116.03  117.84  115.51  ...    115.51    116.8600   20663912.0
# 2018-12-31  177.68  181.58  177.55  ...    177.55    181.4200   17694891.0
#
# [7 rows x 12 columns]

# %%
df['Close'].resample('A').mean().plot(kind='bar',figsize=(16,6))

# %% [markdown]
# # **Time Shifts**

# %%
df
# Out:
#               Open    High     Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                                ...
# 2012-05-18   42.05   45.00   38.00  ...     38.00     38.2318  573576400.0
# 2012-05-21   36.53   36.66   33.00  ...     33.00     34.0300  168192700.0
# 2012-05-22   32.61   33.59   30.94  ...     30.94     31.0000  101786600.0
# 2012-05-23   31.37   32.50   31.36  ...     31.36     32.0000   73600000.0
# 2012-05-24   32.95   33.21   31.77  ...     31.77     33.0300   50237200.0
# ...            ...     ...     ...  ...       ...         ...          ...
# 2018-03-21  164.80  173.40  163.30  ...    163.30    169.3900  105350867.0
# 2018-03-22  166.13  170.27  163.72  ...    163.72    164.8900   73389988.0
# 2018-03-23  165.44  167.10  159.02  ...    159.02    159.3900   52306891.0
# 2018-03-26  160.82  161.10  149.02  ...    149.02    160.0600  125438294.0
# 2018-03-27  156.31  162.85  150.75  ...    150.75    152.1900   76787884.0
#
# [1472 rows x 12 columns]

# %%
df.shift(periods=1).head()
# Out:
#              Open   High    Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 2012-05-18    NaN    NaN    NaN  ...       NaN         NaN          NaN
# 2012-05-21  42.05  45.00  38.00  ...     38.00     38.2318  573576400.0
# 2012-05-22  36.53  36.66  33.00  ...     33.00     34.0300  168192700.0
# 2012-05-23  32.61  33.59  30.94  ...     30.94     31.0000  101786600.0
# 2012-05-24  31.37  32.50  31.36  ...     31.36     32.0000   73600000.0
#
# [5 rows x 12 columns]

# %%
df.shift(periods=-1).tail()
# Out:
#               Open    High     Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                                ...
# 2018-03-21  166.13  170.27  163.72  ...    163.72      164.89   73389988.0
# 2018-03-22  165.44  167.10  159.02  ...    159.02      159.39   52306891.0
# 2018-03-23  160.82  161.10  149.02  ...    149.02      160.06  125438294.0
# 2018-03-26  156.31  162.85  150.75  ...    150.75      152.19   76787884.0
# 2018-03-27     NaN     NaN     NaN  ...       NaN         NaN          NaN
#
# [5 rows x 12 columns]

# %%
df.tshift(freq='M').head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   """Entry point for launching an IPython kernel.
#              Open   High    Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 2012-05-31  42.05  45.00  38.00  ...     38.00     38.2318  573576400.0
# 2012-05-31  36.53  36.66  33.00  ...     33.00     34.0300  168192700.0
# 2012-05-31  32.61  33.59  30.94  ...     30.94     31.0000  101786600.0
# 2012-05-31  31.37  32.50  31.36  ...     31.36     32.0000   73600000.0
# 2012-05-31  32.95  33.21  31.77  ...     31.77     33.0300   50237200.0
#
# [5 rows x 12 columns]

# %% [markdown]
# # **Pandas Rolling and Expanding**

# %%
df
# Out:
#               Open    High     Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                                ...
# 2012-05-18   42.05   45.00   38.00  ...     38.00     38.2318  573576400.0
# 2012-05-21   36.53   36.66   33.00  ...     33.00     34.0300  168192700.0
# 2012-05-22   32.61   33.59   30.94  ...     30.94     31.0000  101786600.0
# 2012-05-23   31.37   32.50   31.36  ...     31.36     32.0000   73600000.0
# 2012-05-24   32.95   33.21   31.77  ...     31.77     33.0300   50237200.0
# ...            ...     ...     ...  ...       ...         ...          ...
# 2018-03-21  164.80  173.40  163.30  ...    163.30    169.3900  105350867.0
# 2018-03-22  166.13  170.27  163.72  ...    163.72    164.8900   73389988.0
# 2018-03-23  165.44  167.10  159.02  ...    159.02    159.3900   52306891.0
# 2018-03-26  160.82  161.10  149.02  ...    149.02    160.0600  125438294.0
# 2018-03-27  156.31  162.85  150.75  ...    150.75    152.1900   76787884.0
#
# [1472 rows x 12 columns]

# %%
df['Open'].plot(figsize=(16,6))

# %%
df.rolling(window=7).mean().head(14)  # moving average
# Out:
#                  Open       High  ...  Adj. Close   Adj. Volume
# Date                              ...
# 2012-05-18        NaN        NaN  ...         NaN           NaN
# 2012-05-21        NaN        NaN  ...         NaN           NaN
# 2012-05-22        NaN        NaN  ...         NaN           NaN
# 2012-05-23        NaN        NaN  ...         NaN           NaN
# 2012-05-24        NaN        NaN  ...         NaN           NaN
# 2012-05-25        NaN        NaN  ...         NaN           NaN
# 2012-05-29  34.270000  35.085714  ...   32.720257  1.546580e+08
# 2012-05-30  32.362143  32.878571  ...   31.285714  8.089966e+07
# 2012-05-31  31.221429  31.880000  ...   30.652857  7.282059e+07
# 2012-06-01  30.690286  31.245714  ...   30.184286  6.425900e+07
# 2012-06-04  30.094571  30.552857  ...   29.455714  5.877761e+07
# 2012-06-05  29.201714  29.774286  ...   28.432714  5.766850e+07
# 2012-06-06  28.226000  28.948571  ...   27.704143  6.114556e+07
# 2012-06-07  27.586000  28.328571  ...   27.342714  5.373071e+07
#
# [14 rows x 12 columns]

# %%
df['Open'].plot()
df.rolling(window=30).mean()['Close'].plot(figsize=(16,6)) # 30 days MA

# %%
# automatic legends by making a column
df['Close 30 Day MA'] = df['Close'].rolling(window=30).mean()
df[['Close', 'Close 30 Day MA']].plot(figsize=(16,6))

# %%
df['Close'].expanding().mean().plot(figsize=(16,6)) # moving average of start date to current position x

# %% [markdown]
# # **Bolinger Band**

# %%
# Close 20 MA
df['Close: 20 Day Mean'] = df['Close'].rolling(20).mean()

# %%
# Upper = 20MA + 2*std(20)
df['Upper'] = df['Close: 20 Day Mean']+2*(df['Close'].rolling(20).std())

# %%
# Lower = 20MA - 2*std(20)
df['Lower'] = df['Close: 20 Day Mean']-2*(df['Close'].rolling(20).std())

# %%
df[['Close', 'Close: 20 Day Mean', 'Upper', 'Lower']].tail(365).plot(figsize=(16,6))
